# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [0.141028, 0.100057, 0.041903, 0.153955, 0.100421, 0.106298, 0.155130, 0.201208]

# %%
plt.bar(x = range(1, 9), height = x)
plt.title('Cluster Distributions')
plt.xlabel('Cluster Number')
plt.ylabel('Relative Proportion of Samples')
# Out:
# Text(0, 0.5, 'Relative Proportion of Samples')
